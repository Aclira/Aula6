# %%
import matplotlib.pyplot as plt
import numpy as np

def func(t):
    return (3-(2*t))

def func2(t):
    return ((-2-t)/-3)

n = np.linspace(-10,10, num=100)

plt.plot(n, func(n))
plt.plot(n, func2(n))

plt.title('One solution')
plt.show()

# %%
a = np.array([[2,1], [1,-3]])
b = np.array([3,-2])
x = np.linalg.solve(a,b)
x
# Out:
# array([1., 1.])

# %%
np.allclose(np.dot(a,x),b)
# Out:
# True

# %%
def func(t):
    return (3-(2*t))

def func2(t):
    return ((6-(t*4))/2)

n = np.linspace(-10,10, num = 100)

plt.plot(n, func(n))
plt.plot(n, func2(n))

plt.title('Infinite solutions')
plt.show()

# %%
def func(t):
    return (3-(t*2))

def func2(t):
    return ((2-(t*4))/2)

n = np.linspace(-10,10, num=100)

plt.plot(n, func(n))
plt.plot(n, func2(n))

plt.title('No solution')
plt.show()

# %%
#Para encontrar o Angulo é feito o calculo do coeficiente angular
def func(vet, vet2):
    return (vet[1]/vet[0])*vet2

vetT = np.linspace(0, 1, num = 10)
uT = np.linspace(0, 2, num = 10)

A = np.matrix([[2, 1],[1, -3]])

vet = np.array([1, 1])
u = np.matmul(A.data, vet)

plt.plot(vetT, func(vet, vetT), "b")
plt.plot(uT,func(u, uT), "r")


plt.title('Gráfico 1')
plt.show()


vetT = np.linspace(0, 5, num = 10)
uT = np.linspace(0, 3, num = 10)



plt.plot(vetT, func(vet, vetT), "b")
plt.plot(uT, func(u, uT), "r")

plt.title('Gráfico 2')
plt.show()

# %% [markdown]
# # Imagem de A

# %%
#Para encontrar o Angulo é feito o calculo do coeficiente angular
def func(vet, x):
    return (vet[1]/vet[0])*x

a = np.array([2,1])
b = np.array([1, -3])


x1 = 2
x2 = 1

a1 = x1 * a
b1 = x2 * b

u = a1 + b1


aT = np.linspace(0, 5)
uT = np.linspace(0, 6)
bT = np.linspace(0, 3)


plt.plot(aT, func(a1, aT), "b")
plt.plot(uT, func(u, uT), "r")
plt.plot(bT, func(b1, bT), "y")

plt.title('Imagem de A')
plt.show()
